# %% [markdown]
# ## <u> Use only those concepts which have been taught till now </u>

# %% [markdown]
# # <b> Problem 1: Import Pandas and Numpy in the notebook </b>

# %%
# Import statements

import pandas as pd
import numpy as np

# %% [markdown]
# # <b> Problem 2 : Load the automobile_data.csv kept in the shared folder

# %%
# Mount your drive and read the csv file. Make sure you are using the correct file path

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
working = "/content/drive/MyDrive/Almabetter/Untitled folder/dat/"
imdf = pd.read_csv(working + "automobile_data.csv")

# %% [markdown]
# # <b> Problem 3 : Do a basic inspection and print the first and last 15 rows of your dataframe

# %%
# Your code here
df=pd.concat([imdf.head(15), imdf.tail(15)])
print(df)
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            3                 ?  alfa-romero       gas        std
# 2            1                 ?  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# 5            2                 ?         audi       gas        std
# 6            1               158         audi       gas        std
# 7            1                 ?         audi       gas        std
# 8            1               158         audi       gas      turbo
# 9            0                 ?         audi       gas      turbo
# 10           2               192          bmw       gas        std
# 11           0               192          bmw       gas        std
# 12           0               188          bmw       gas        std
# 13           0               188          bmw       gas        std
# 14           1                 ?          bmw       gas        std
# 190          3               256   volkswagen       gas        std
# 191          0                 ?   volkswagen       gas        std
# 192          0                 ?   volkswagen    diesel      turbo
# 193          0                 ?   volkswagen       gas        std
# 194         -2               103        volvo       gas        std
# 195         -1                74        volvo       gas        std
# 196         -2               103        volvo       gas        std
# 197         -1                74        volvo       gas        std
# 198         -2               103        volvo       gas      turbo
# 199         -1                74        volvo       gas      turbo
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# 1            two  convertible          rwd           front        88.6  ...
# 2            two    hatchback          rwd           front        94.5  ...
# 3           four        sedan          fwd           front        99.8  ...
# 4           four        sedan          4wd           front        99.4  ...
# 5            two        sedan          fwd           front        99.8  ...
# 6           four        sedan          fwd           front       105.8  ...
# 7           four        wagon          fwd           front       105.8  ...
# 8           four        sedan          fwd           front       105.8  ...
# 9            two    hatchback          4wd           front        99.5  ...
# 10           two        sedan          rwd           front       101.2  ...
# 11          four        sedan          rwd           front       101.2  ...
# 12           two        sedan          rwd           front       101.2  ...
# 13          four        sedan          rwd           front       101.2  ...
# 14          four        sedan          rwd           front       103.5  ...
# 190          two    hatchback          fwd           front        94.5  ...
# 191         four        sedan          fwd           front       100.4  ...
# 192         four        sedan          fwd           front       100.4  ...
# 193         four        wagon          fwd           front       100.4  ...
# 194         four        sedan          rwd           front       104.3  ...
# 195         four        wagon          rwd           front       104.3  ...
# 196         four        sedan          rwd           front       104.3  ...
# 197         four        wagon          rwd           front       104.3  ...
# 198         four        sedan          rwd           front       104.3  ...
# 199         four        wagon          rwd           front       104.3  ...
# 200         four        sedan          rwd           front       109.1  ...
# 201         four        sedan          rwd           front       109.1  ...
# 202         four        sedan          rwd           front       109.1  ...
# 203         four        sedan          rwd           front       109.1  ...
# 204         four        sedan          rwd           front       109.1  ...
#
#      engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# 0            130         mpfi  3.47    2.68               9.0        111
# 1            130         mpfi  3.47    2.68               9.0        111
# 2            152         mpfi  2.68    3.47               9.0        154
# 3            109         mpfi  3.19     3.4              10.0        102
# 4            136         mpfi  3.19     3.4               8.0        115
# 5            136         mpfi  3.19     3.4               8.5        110
# 6            136         mpfi  3.19     3.4               8.5        110
# 7            136         mpfi  3.19     3.4               8.5        110
# 8            131         mpfi  3.13     3.4               8.3        140
# 9            131         mpfi  3.13     3.4               7.0        160
# 10           108         mpfi   3.5     2.8               8.8        101
# 11           108         mpfi   3.5     2.8               8.8        101
# 12           164         mpfi  3.31    3.19               9.0        121
# 13           164         mpfi  3.31    3.19               9.0        121
# 14           164         mpfi  3.31    3.19               9.0        121
# 190          109         mpfi  3.19     3.4               8.5         90
# 191          136         mpfi  3.19     3.4               8.5        110
# 192           97          idi  3.01     3.4              23.0         68
# 193          109         mpfi  3.19     3.4               9.0         88
# 194          141         mpfi  3.78    3.15               9.5        114
# 195          141         mpfi  3.78    3.15               9.5        114
# 196          141         mpfi  3.78    3.15               9.5        114
# 197          141         mpfi  3.78    3.15               9.5        114
# 198          130         mpfi  3.62    3.15               7.5        162
# 199          130         mpfi  3.62    3.15               7.5        162
# 200          141         mpfi  3.78    3.15               9.5        114
# 201          141         mpfi  3.78    3.15               8.7        160
# 202          173         mpfi  3.58    2.87               8.8        134
# 203          145          idi  3.01     3.4              23.0        106
# 204          141         mpfi  3.78    3.15               9.5        114
#
#      peak-rpm city-mpg highway-mpg  price
# 0        5000       21          27  13495
# 1        5000       21          27  16500
# 2        5000       19          26  16500
# 3        5500       24          30  13950
# 4        5500       18          22  17450
# 5        5500       19          25  15250
# 6        5500       19          25  17710
# 7        5500       19          25  18920
# 8        5500       17          20  23875
# 9        5500       16          22      ?
# 10       5800       23          29  16430
# 11       5800       23          29  16925
# 12       4250       21          28  20970
# 13       4250       21          28  21105
# 14       4250       20          25  24565
# 190      5500       24          29   9980
# 191      5500       19          24  13295
# 192      4500       33          38  13845
# 193      5500       25          31  12290
# 194      5400       23          28  12940
# 195      5400       23          28  13415
# 196      5400       24          28  15985
# 197      5400       24          28  16515
# 198      5100       17          22  18420
# 199      5100       17          22  18950
# 200      5400       23          28  16845
# 201      5300       19          25  19045
# 202      5500       18          23  21485
# 203      4800       26          27  22470
# 204      5400       19          25  22625
#
# [30 rows x 26 columns]

# %% [markdown]
# # <b>Problem 4 : You need to clean the data a little bit now. Replace all column values with the values <code>?</code> and <code>n.a</code> with <code>NaN</code>

# %%
# Your code here
df.replace(['?', 'n.a'], '0', inplace=True)
print(df)
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 0  alfa-romero       gas        std
# 1            3                 0  alfa-romero       gas        std
# 2            1                 0  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# 5            2                 0         audi       gas        std
# 6            1               158         audi       gas        std
# 7            1                 0         audi       gas        std
# 8            1               158         audi       gas      turbo
# 9            0                 0         audi       gas      turbo
# 10           2               192          bmw       gas        std
# 11           0               192          bmw       gas        std
# 12           0               188          bmw       gas        std
# 13           0               188          bmw       gas        std
# 14           1                 0          bmw       gas        std
# 190          3               256   volkswagen       gas        std
# 191          0                 0   volkswagen       gas        std
# 192          0                 0   volkswagen    diesel      turbo
# 193          0                 0   volkswagen       gas        std
# 194         -2               103        volvo       gas        std
# 195         -1                74        volvo       gas        std
# 196         -2               103        volvo       gas        std
# 197         -1                74        volvo       gas        std
# 198         -2               103        volvo       gas      turbo
# 199         -1                74        volvo       gas      turbo
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# 1            two  convertible          rwd           front        88.6  ...
# 2            two    hatchback          rwd           front        94.5  ...
# 3           four        sedan          fwd           front        99.8  ...
# 4           four        sedan          4wd           front        99.4  ...
# 5            two        sedan          fwd           front        99.8  ...
# 6           four        sedan          fwd           front       105.8  ...
# 7           four        wagon          fwd           front       105.8  ...
# 8           four        sedan          fwd           front       105.8  ...
# 9            two    hatchback          4wd           front        99.5  ...
# 10           two        sedan          rwd           front       101.2  ...
# 11          four        sedan          rwd           front       101.2  ...
# 12           two        sedan          rwd           front       101.2  ...
# 13          four        sedan          rwd           front       101.2  ...
# 14          four        sedan          rwd           front       103.5  ...
# 190          two    hatchback          fwd           front        94.5  ...
# 191         four        sedan          fwd           front       100.4  ...
# 192         four        sedan          fwd           front       100.4  ...
# 193         four        wagon          fwd           front       100.4  ...
# 194         four        sedan          rwd           front       104.3  ...
# 195         four        wagon          rwd           front       104.3  ...
# 196         four        sedan          rwd           front       104.3  ...
# 197         four        wagon          rwd           front       104.3  ...
# 198         four        sedan          rwd           front       104.3  ...
# 199         four        wagon          rwd           front       104.3  ...
# 200         four        sedan          rwd           front       109.1  ...
# 201         four        sedan          rwd           front       109.1  ...
# 202         four        sedan          rwd           front       109.1  ...
# 203         four        sedan          rwd           front       109.1  ...
# 204         four        sedan          rwd           front       109.1  ...
#
#      engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# 0            130         mpfi  3.47    2.68               9.0        111
# 1            130         mpfi  3.47    2.68               9.0        111
# 2            152         mpfi  2.68    3.47               9.0        154
# 3            109         mpfi  3.19     3.4              10.0        102
# 4            136         mpfi  3.19     3.4               8.0        115
# 5            136         mpfi  3.19     3.4               8.5        110
# 6            136         mpfi  3.19     3.4               8.5        110
# 7            136         mpfi  3.19     3.4               8.5        110
# 8            131         mpfi  3.13     3.4               8.3        140
# 9            131         mpfi  3.13     3.4               7.0        160
# 10           108         mpfi   3.5     2.8               8.8        101
# 11           108         mpfi   3.5     2.8               8.8        101
# 12           164         mpfi  3.31    3.19               9.0        121
# 13           164         mpfi  3.31    3.19               9.0        121
# 14           164         mpfi  3.31    3.19               9.0        121
# 190          109         mpfi  3.19     3.4               8.5         90
# 191          136         mpfi  3.19     3.4               8.5        110
# 192           97          idi  3.01     3.4              23.0         68
# 193          109         mpfi  3.19     3.4               9.0         88
# 194          141         mpfi  3.78    3.15               9.5        114
# 195          141         mpfi  3.78    3.15               9.5        114
# 196          141         mpfi  3.78    3.15               9.5        114
# 197          141         mpfi  3.78    3.15               9.5        114
# 198          130         mpfi  3.62    3.15               7.5        162
# 199          130         mpfi  3.62    3.15               7.5        162
# 200          141         mpfi  3.78    3.15               9.5        114
# 201          141         mpfi  3.78    3.15               8.7        160
# 202          173         mpfi  3.58    2.87               8.8        134
# 203          145          idi  3.01     3.4              23.0        106
# 204          141         mpfi  3.78    3.15               9.5        114
#
#      peak-rpm city-mpg highway-mpg  price
# 0        5000       21          27  13495
# 1        5000       21          27  16500
# 2        5000       19          26  16500
# 3        5500       24          30  13950
# 4        5500       18          22  17450
# 5        5500       19          25  15250
# 6        5500       19          25  17710
# 7        5500       19          25  18920
# 8        5500       17          20  23875
# 9        5500       16          22      0
# 10       5800       23          29  16430
# 11       5800       23          29  16925
# 12       4250       21          28  20970
# 13       4250       21          28  21105
# 14       4250       20          25  24565
# 190      5500       24          29   9980
# 191      5500       19          24  13295
# 192      4500       33          38  13845
# 193      5500       25          31  12290
# 194      5400       23          28  12940
# 195      5400       23          28  13415
# 196      5400       24          28  15985
# 197      5400       24          28  16515
# 198      5100       17          22  18420
# 199      5100       17          22  18950
# 200      5400       23          28  16845
# 201      5300       19          25  19045
# 202      5500       18          23  21485
# 203      4800       26          27  22470
# 204      5400       19          25  22625
#
# [30 rows x 26 columns]

# %% [markdown]
# # <b>Problem 5 : Print the company name which manufactured the most expensive car. Also print the price of the most expensive car

# %%
# Your code here
df['price'].astype(int)
df['price'].max()
# Out:
# '9980'

# %% [markdown]
# # <b>Problem 6 : Calculate maximum horsepowers for each company. </b>

# %%
# Your code here
list_un=list(df['make'].unique())
for i in list_un:
  d2=df.loc[df['make']==i ,'horsepower']
  print(i)
  print(d2.max())
# Out:
# alfa-romero
# 154
# audi
# 160
# bmw
# 121
# volkswagen
# 90
# volvo
# 162

# %% [markdown]
# # <b> Problem 7 : Print the total number of cars manufactured by each company

# %%
# Your code here
df['make'].value_counts()
# Out:
# volvo          11
# audi            7
# bmw             5
# volkswagen      4
# alfa-romero     3
# Name: make, dtype: int64

# %% [markdown]
# # <b> Problem 8 : Create a new column for the updated price. This updated price will be calculated on top of the given price - if the engine is in front, price will be same else if the engine is in rear, price will be doubled </b>

# %%
# Your code here. Use apply and lambda
df['price']=df['price'].astype(int)
def update(a, b):
  if a=="front":
    pass
  elif a=="rear":
    b+=b
  else:
    pass

  print(b)  


df['updated_price'] = df.apply(lambda x:update(x['engine-location'],x['price']), axis=1)
print(df)
# Out:
# 13495
# 16500
# 16500
# 13950
# 17450
# 15250
# 17710
# 18920
# 23875
# 0
# 16430
# 16925
# 20970
# 21105
# 24565
# 9980
# 13295
# 13845
# 12290
# 12940
# 13415
# 15985
# 16515
# 18420
# 18950
# 16845
# 19045
# 21485
# 22470
# 22625
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 0  alfa-romero       gas        std
# 1            3                 0  alfa-romero       gas        std
# 2            1                 0  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# 5            2                 0         audi       gas        std
# 6            1               158         audi       gas        std
# 7            1                 0         audi       gas        std
# 8            1               158         audi       gas      turbo
# 9            0                 0         audi       gas      turbo
# 10           2               192          bmw       gas        std
# 11           0               192          bmw       gas        std
# 12           0               188          bmw       gas        std
# 13           0               188          bmw       gas        std
# 14           1                 0          bmw       gas        std
# 190          3               256   volkswagen       gas        std
# 191          0                 0   volkswagen       gas        std
# 192          0                 0   volkswagen    diesel      turbo
# 193          0                 0   volkswagen       gas        std
# 194         -2               103        volvo       gas        std
# 195         -1                74        volvo       gas        std
# 196         -2               103        volvo       gas        std
# 197         -1                74        volvo       gas        std
# 198         -2               103        volvo       gas      turbo
# 199         -1                74        volvo       gas      turbo
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0              2  convertible          rwd           front        88.6  ...
# 1              2  convertible          rwd           front        88.6  ...
# 2              2    hatchback          rwd           front        94.5  ...
# 3              4        sedan          fwd           front        99.8  ...
# 4              4        sedan          4wd           front        99.4  ...
# 5              2        sedan          fwd           front        99.8  ...
# 6              4        sedan          fwd           front       105.8  ...
# 7              4        wagon          fwd           front       105.8  ...
# 8              4        sedan          fwd           front       105.8  ...
# 9              2    hatchback          4wd           front        99.5  ...
# 10             2        sedan          rwd           front       101.2  ...
# 11             4        sedan          rwd           front       101.2  ...
# 12             2        sedan          rwd           front       101.2  ...
# 13             4        sedan          rwd           front       101.2  ...
# 14             4        sedan          rwd           front       103.5  ...
# 190            2    hatchback          fwd           front        94.5  ...
# 191            4        sedan          fwd           front       100.4  ...
# 192            4        sedan          fwd           front       100.4  ...
# 193            4        wagon          fwd           front       100.4  ...
# 194            4        sedan          rwd           front       104.3  ...
# 195            4        wagon          rwd           front       104.3  ...
# 196            4        sedan          rwd           front       104.3  ...
# 197            4        wagon          rwd           front       104.3  ...
# 198            4        sedan          rwd           front       104.3  ...
# 199            4        wagon          rwd           front       104.3  ...
# 200            4        sedan          rwd           front       109.1  ...
# 201            4        sedan          rwd           front       109.1  ...
# 202            4        sedan          rwd           front       109.1  ...
# 203            4        sedan          rwd           front       109.1  ...
# 204            4        sedan          rwd           front       109.1  ...
#
#      bore  stroke  compression-ratio  horsepower peak-rpm city-mpg  \
# 0    3.47    2.68                9.0         111     5000       21
# 1    3.47    2.68                9.0         111     5000       21
# 2    2.68    3.47                9.0         154     5000       19
# 3    3.19     3.4               10.0         102     5500       24
# 4    3.19     3.4                8.0         115     5500       18
# 5    3.19     3.4                8.5         110     5500       19
# 6    3.19     3.4                8.5         110     5500       19
# 7    3.19     3.4                8.5         110     5500       19
# 8    3.13     3.4                8.3         140     5500       17
# 9    3.13     3.4                7.0         160     5500       16
# 10    3.5     2.8                8.8         101     5800       23
# 11    3.5     2.8                8.8         101     5800       23
# 12   3.31    3.19                9.0         121     4250       21
# 13   3.31    3.19                9.0         121     4250       21
# 14   3.31    3.19                9.0         121     4250       20
# 190  3.19     3.4                8.5          90     5500       24
# 191  3.19     3.4                8.5         110     5500       19
# 192  3.01     3.4               23.0          68     4500       33
# 193  3.19     3.4                9.0          88     5500       25
# 194  3.78    3.15                9.5         114     5400       23
# 195  3.78    3.15                9.5         114     5400       23
# 196  3.78    3.15                9.5         114     5400       24
# 197  3.78    3.15                9.5         114     5400       24
# 198  3.62    3.15                7.5         162     5100       17
# 199  3.62    3.15                7.5         162     5100       17
# 200  3.78    3.15                9.5         114     5400       23
# 201  3.78    3.15                8.7         160     5300       19
# 202  3.58    2.87                8.8         134     5500       18
# 203  3.01     3.4               23.0         106     4800       26
# 204  3.78    3.15                9.5         114     5400       19
#
#      highway-mpg  price new_num-of-doors updated_price
# 0             27  13495                2          None
# 1             27  16500                2          None
# 2             26  16500                2          None
# 3             30  13950                4          None
# 4             22  17450                4          None
# 5             25  15250                2          None
# 6             25  17710                4          None
# 7             25  18920                4          None
# 8             20  23875                4          None
# 9             22      0                2          None
# 10            29  16430                2          None
# 11            29  16925                4          None
# 12            28  20970                2          None
# 13            28  21105                4          None
# 14            25  24565                4          None
# 190           29   9980                2          None
# 191           24  13295                4          None
# 192           38  13845                4          None
# 193           31  12290                4          None
# 194           28  12940                4          None
# 195           28  13415                4          None
# 196           28  15985                4          None
# 197           28  16515                4          None
# 198           22  18420                4          None
# 199           22  18950                4          None
# 200           28  16845                4          None
# 201           25  19045                4          None
# 202           23  21485                4          None
# 203           27  22470                4          None
# 204           25  22625                4          None
#
# [30 rows x 28 columns]

# %% [markdown]
# # <b>Problem 9 : Sort the dataframe by car and price columns

# %%
# Your code here

df.sort_values(['price','make'], ascending=[True,False])
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 9            0                 0         audi       gas      turbo
# 193          0                 0   volkswagen       gas        std
# 194         -2               103        volvo       gas        std
# 191          0                 0   volkswagen       gas        std
# 195         -1                74        volvo       gas        std
# 0            3                 0  alfa-romero       gas        std
# 192          0                 0   volkswagen    diesel      turbo
# 3            2               164         audi       gas        std
# 5            2                 0         audi       gas        std
# 196         -2               103        volvo       gas        std
# 10           2               192          bmw       gas        std
# 1            3                 0  alfa-romero       gas        std
# 2            1                 0  alfa-romero       gas        std
# 197         -1                74        volvo       gas        std
# 200         -1                95        volvo       gas        std
# 11           0               192          bmw       gas        std
# 4            2               164         audi       gas        std
# 6            1               158         audi       gas        std
# 198         -2               103        volvo       gas      turbo
# 7            1                 0         audi       gas        std
# 199         -1                74        volvo       gas      turbo
# 201         -1                95        volvo       gas      turbo
# 12           0               188          bmw       gas        std
# 13           0               188          bmw       gas        std
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
# 8            1               158         audi       gas      turbo
# 14           1                 0          bmw       gas        std
# 190          3               256   volkswagen       gas        std
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 9            two    hatchback          4wd           front        99.5  ...
# 193         four        wagon          fwd           front       100.4  ...
# 194         four        sedan          rwd           front       104.3  ...
# 191         four        sedan          fwd           front       100.4  ...
# 195         four        wagon          rwd           front       104.3  ...
# 0            two  convertible          rwd           front        88.6  ...
# 192         four        sedan          fwd           front       100.4  ...
# 3           four        sedan          fwd           front        99.8  ...
# 5            two        sedan          fwd           front        99.8  ...
# 196         four        sedan          rwd           front       104.3  ...
# 10           two        sedan          rwd           front       101.2  ...
# 1            two  convertible          rwd           front        88.6  ...
# 2            two    hatchback          rwd           front        94.5  ...
# 197         four        wagon          rwd           front       104.3  ...
# 200         four        sedan          rwd           front       109.1  ...
# 11          four        sedan          rwd           front       101.2  ...
# 4           four        sedan          4wd           front        99.4  ...
# 6           four        sedan          fwd           front       105.8  ...
# 198         four        sedan          rwd           front       104.3  ...
# 7           four        wagon          fwd           front       105.8  ...
# 199         four        wagon          rwd           front       104.3  ...
# 201         four        sedan          rwd           front       109.1  ...
# 12           two        sedan          rwd           front       101.2  ...
# 13          four        sedan          rwd           front       101.2  ...
# 202         four        sedan          rwd           front       109.1  ...
# 203         four        sedan          rwd           front       109.1  ...
# 204         four        sedan          rwd           front       109.1  ...
# 8           four        sedan          fwd           front       105.8  ...
# 14          four        sedan          rwd           front       103.5  ...
# 190          two    hatchback          fwd           front        94.5  ...
#
#      engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# 9            131         mpfi  3.13     3.4               7.0        160
# 193          109         mpfi  3.19     3.4               9.0         88
# 194          141         mpfi  3.78    3.15               9.5        114
# 191          136         mpfi  3.19     3.4               8.5        110
# 195          141         mpfi  3.78    3.15               9.5        114
# 0            130         mpfi  3.47    2.68               9.0        111
# 192           97          idi  3.01     3.4              23.0         68
# 3            109         mpfi  3.19     3.4              10.0        102
# 5            136         mpfi  3.19     3.4               8.5        110
# 196          141         mpfi  3.78    3.15               9.5        114
# 10           108         mpfi   3.5     2.8               8.8        101
# 1            130         mpfi  3.47    2.68               9.0        111
# 2            152         mpfi  2.68    3.47               9.0        154
# 197          141         mpfi  3.78    3.15               9.5        114
# 200          141         mpfi  3.78    3.15               9.5        114
# 11           108         mpfi   3.5     2.8               8.8        101
# 4            136         mpfi  3.19     3.4               8.0        115
# 6            136         mpfi  3.19     3.4               8.5        110
# 198          130         mpfi  3.62    3.15               7.5        162
# 7            136         mpfi  3.19     3.4               8.5        110
# 199          130         mpfi  3.62    3.15               7.5        162
# 201          141         mpfi  3.78    3.15               8.7        160
# 12           164         mpfi  3.31    3.19               9.0        121
# 13           164         mpfi  3.31    3.19               9.0        121
# 202          173         mpfi  3.58    2.87               8.8        134
# 203          145          idi  3.01     3.4              23.0        106
# 204          141         mpfi  3.78    3.15               9.5        114
# 8            131         mpfi  3.13     3.4               8.3        140
# 14           164         mpfi  3.31    3.19               9.0        121
# 190          109         mpfi  3.19     3.4               8.5         90
#
#      peak-rpm city-mpg highway-mpg  price
# 9        5500       16          22      0
# 193      5500       25          31  12290
# 194      5400       23          28  12940
# 191      5500       19          24  13295
# 195      5400       23          28  13415
# 0        5000       21          27  13495
# 192      4500       33          38  13845
# 3        5500       24          30  13950
# 5        5500       19          25  15250
# 196      5400       24          28  15985
# 10       5800       23          29  16430
# 1        5000       21          27  16500
# 2        5000       19          26  16500
# 197      5400       24          28  16515
# 200      5400       23          28  16845
# 11       5800       23          29  16925
# 4        5500       18          22  17450
# 6        5500       19          25  17710
# 198      5100       17          22  18420
# 7        5500       19          25  18920
# 199      5100       17          22  18950
# 201      5300       19          25  19045
# 12       4250       21          28  20970
# 13       4250       21          28  21105
# 202      5500       18          23  21485
# 203      4800       26          27  22470
# 204      5400       19          25  22625
# 8        5500       17          20  23875
# 14       4250       20          25  24565
# 190      5500       24          29   9980
#
# [30 rows x 26 columns]

# %% [markdown]
# # <b> Problem 10 : Create a new column which stores the number of doors in a car as integers.

# %%
# Your code here. Use apply
df['new_num-of-doors']=df['num-of-doors'].astype('string')
for i in df['new_num-of-doors']:
  if i=="two":
    df['new_num-of-doors'].replace('two', '2', inplace=True)    
  else:
    df['new_num-of-doors'].replace('four', '4',inplace=True)  

df['new_num-of-doors']=df['new_num-of-doors'].astype(int)
df.head()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30 entries, 0 to 204
# Data columns (total 27 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          30 non-null     int64
#  1   normalized-losses  30 non-null     object
#  2   make               30 non-null     object
#  3   fuel-type          30 non-null     object
#  4   aspiration         30 non-null     object
#  5   num-of-doors       30 non-null     object
#  6   body-style         30 non-null     object
#  7   drive-wheels       30 non-null     object
#  8   engine-location    30 non-null     object
#  9   wheel-base         30 non-null     float64
#  10  length             30 non-null     float64
#  11  width              30 non-null     float64
#  12  height             30 non-null     float64
#  13  curb-weight        30 non-null     int64
#  14  engine-type        30 non-null     object
#  15  num-of-cylinders   30 non-null     object
#  16  engine-size        30 non-null     int64
#  17  fuel-system        30 non-null     object
#  18  bore               30 non-null     object
#  19  stroke             30 non-null     object
#  20  compression-ratio  30 non-null     float64
#  21  horsepower         30 non-null     object
#  22  peak-rpm           30 non-null     object
#  23  city-mpg           30 non-null     int64
#  24  highway-mpg        30 non-null     int64
#  25  price              30 non-null     object
#  26  new_num-of-doors   30 non-null     int64
# dtypes: float64(5), int64(6), object(16)
# memory usage: 6.6+ KB

# %% [markdown]
# # <b>Problem 11 : Concatenate the two data frames given below firstly row wise and secondly column wise.</b>
#
# <code>GermanCars = {'Company': ['Ford', 'Mercedes', 'BMV', 'Audi'], 'Price': [23845, 171995, 135925 , 71400]}</code>
#
# <code>japaneseCars = {'Company': ['Toyota', 'Honda', 'Nissan', 'Mitsubishi '], 'Price': [29995, 23600, 61500 , 58900]}</code>

# %%
# Your code here
GermanCars = {'Company': ['Ford', 'Mercedes', 'BMV', 'Audi'], 'Price': [23845, 171995, 135925 , 71400]}
japaneseCars = {'Company': ['Toyota', 'Honda', 'Nissan', 'Mitsubishi '], 'Price': [29995, 23600, 61500 , 58900]}
GermanCars_df = pd.DataFrame(GermanCars)
japaneseCars_df = pd.DataFrame(japaneseCars)
frames = [GermanCars_df, japaneseCars_df]
df_1 = pd.concat(frames, axis=1)
print(df_1)
# Out:
#     Company   Price      Company  Price
# 0      Ford   23845       Toyota  29995
# 1  Mercedes  171995        Honda  23600
# 2       BMV  135925       Nissan  61500
# 3      Audi   71400  Mitsubishi   58900
